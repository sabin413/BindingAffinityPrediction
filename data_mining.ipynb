# %% [markdown]
# This code parses a sdf data file and makes a dataframe extracting text and numbers from there.

# %% [markdown]
# ####  About BindingDB https://www.bindingdb.org/rwd/bind/chemsearch/marvin/Download.jsp
# It is a database of experimentally determined protein-ligand binding affinities, currently containing binding affinities for about 20, 000 protein-ligand pairs from 110 proteins and about 11000 smal molecules.

# %%
# The following code reads through the data, for each protein-ligand pair it reads 'PubChem SID', 
# 'BindingDB Target Chain Sequence', 'Number of Protein Chains in Target', and '<Kd '. Note that 'PubChem SID' is an 
# ID number for a ligand, which we will use later to get their SMILES
# reads the file line by line, looks for key words/phrases and reads 
# relevant data from the lines immediately following

# %%
import numpy as np
import pandas as pd
import re

# %%
file_path = "BindingDB_All_3D.sdf"

df = pd.DataFrame(columns = ["kd", "ligand_cid", "no_of_complexes", "protein_seq"])
print(df)
# Out:
# Empty DataFrame
# Columns: [kd, ligand_cid, no_of_complexes, protein_seq]
# Index: []

# %%
chunk_size = 1024*1024*1024 # 1 GB
row_dict = {}
flag_lig, flag_pr, flag_noc, flag_kd = False, False, False, False

def process_chunk(chunk):
    global row_dict, flag_lig, flag_pr, flag_noc, flag_kd  # Declare row_dict as global to modify the global variable inside the function
    
    for line in chunk:
        line = line.rstrip()
        
        if bool(re.search('PubChem SID', line)):
            flag_lig = True
            continue
        elif bool(re.search('BindingDB Target Chain Sequence', line)):
            flag_pr = True
            continue
        elif bool(re.search('Number of Protein Chains in Target', line)):
            flag_noc = True
            continue
        elif bool(re.search('<Kd', line)):
            flag_kd = True
            continue
        
        if flag_lig == True:
            try:
                line = int(line.strip())
            except:
                line = np.nan
            row_dict['ligand_cid'] = line
            flag_lig = False
        elif flag_pr == True:
            row_dict['protein_seq'] = line.strip()
            flag_pr = False
        elif flag_noc == True:
            try:
                line = int(line.strip())
            except:
                line = np.nan
            row_dict['no_of_complexes'] = line
            flag_noc = False
        elif flag_kd == True:
            try:
                line = float(line.strip())
            except:
            #print(line)
                line = np.nan
            row_dict['kd'] = line
            flag_kd = False
      
        
        if len(list(row_dict.keys())) == 4:
            #print(True)
            df.loc[len(df.index)] = row_dict
            row_dict = {}

c = 0 # to moniter progress
        
with open(file_path, 'r', encoding="utf8") as file:
    while True:
        # Read up to chunk_size bytes from the file
        lines = list(file.readlines(chunk_size))
        
        # If lines is empty, we've reached the end of the file
        if not lines:
            break
        c += 1
        # Process the current chunk of lines
        process_chunk(lines)
        print(c)
        print(df.info())
        df.to_csv('df_raw.csv', index = False)
        
print(df.shape)
print(df.info())
# Out:
# 1
# <class 'pandas.core.frame.DataFrame'>
# Index: 134450 entries, 0 to 134449
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               3438 non-null    float64
#  1   ligand_cid       134450 non-null  int64
#  2   no_of_complexes  134450 non-null  int64
#  3   protein_seq      134450 non-null  object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 5.1+ MB
# None
# 2
# <class 'pandas.core.frame.DataFrame'>
# Index: 259598 entries, 0 to 259597
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               4498 non-null    float64
#  1   ligand_cid       259598 non-null  int64
#  2   no_of_complexes  259598 non-null  int64
#  3   protein_seq      259598 non-null  object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 9.9+ MB
# None
# 3
# <class 'pandas.core.frame.DataFrame'>
# Index: 381972 entries, 0 to 381971
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               5555 non-null    float64
#  1   ligand_cid       381972 non-null  int64
#  2   no_of_complexes  381972 non-null  int64
#  3   protein_seq      381972 non-null  object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 14.6+ MB
# None
# 4
# <class 'pandas.core.frame.DataFrame'>
# Index: 503142 entries, 0 to 503141
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               6584 non-null    float64
#  1   ligand_cid       503048 non-null  float64
#  2   no_of_complexes  503142 non-null  int64
#  3   protein_seq      503142 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 19.2+ MB
# None
# 5
# <class 'pandas.core.frame.DataFrame'>
# Index: 623965 entries, 0 to 623964
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               7688 non-null    float64
#  1   ligand_cid       623855 non-null  float64
#  2   no_of_complexes  623965 non-null  int64
#  3   protein_seq      623965 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 23.8+ MB
# None
# 6
# <class 'pandas.core.frame.DataFrame'>
# Index: 743684 entries, 0 to 743683
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               8696 non-null    float64
#  1   ligand_cid       742625 non-null  float64
#  2   no_of_complexes  743684 non-null  int64
#  3   protein_seq      743684 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 28.4+ MB
# None
# 7
# <class 'pandas.core.frame.DataFrame'>
# Index: 863895 entries, 0 to 863894
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               9621 non-null    float64
#  1   ligand_cid       856885 non-null  float64
#  2   no_of_complexes  863895 non-null  int64
#  3   protein_seq      863895 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 33.0+ MB
# None
# 8
# <class 'pandas.core.frame.DataFrame'>
# Index: 982443 entries, 0 to 982442
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   kd               11366 non-null   float64
#  1   ligand_cid       970452 non-null  float64
#  2   no_of_complexes  982443 non-null  int64
#  3   protein_seq      982443 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 37.5+ MB
# None
# 9
# <class 'pandas.core.frame.DataFrame'>
# Index: 1096950 entries, 0 to 1096949
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               14571 non-null    float64
#  1   ligand_cid       1063166 non-null  float64
#  2   no_of_complexes  1096950 non-null  int64
#  3   protein_seq      1096950 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 41.8+ MB
# None
# 10
# <class 'pandas.core.frame.DataFrame'>
# Index: 1216829 entries, 0 to 1216828
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               16342 non-null    float64
#  1   ligand_cid       1183045 non-null  float64
#  2   no_of_complexes  1216829 non-null  int64
#  3   protein_seq      1216829 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 46.4+ MB
# None
# 11
# <class 'pandas.core.frame.DataFrame'>
# Index: 1334795 entries, 0 to 1334794
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               22552 non-null    float64
#  1   ligand_cid       1301011 non-null  float64
#  2   no_of_complexes  1334795 non-null  int64
#  3   protein_seq      1334795 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 50.9+ MB
# None
# 12
# <class 'pandas.core.frame.DataFrame'>
# Index: 1454794 entries, 0 to 1454793
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               24140 non-null    float64
#  1   ligand_cid       1421010 non-null  float64
#  2   no_of_complexes  1454794 non-null  int64
#  3   protein_seq      1454794 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 55.5+ MB
# None
# 13
# <class 'pandas.core.frame.DataFrame'>
# Index: 1569430 entries, 0 to 1569429
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               26030 non-null    float64
#  1   ligand_cid       1535646 non-null  float64
#  2   no_of_complexes  1569430 non-null  int64
#  3   protein_seq      1569430 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 59.9+ MB
# None
# 14
# <class 'pandas.core.frame.DataFrame'>
# Index: 1690460 entries, 0 to 1690459
# Data columns (total 4 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   kd               27711 non-null    float64
#  1   ligand_cid       1656676 non-null  float64
#  2   no_of_complexes  1690460 non-null  int64
#  3   protein_seq      1690460 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 64.5+ MB
# None
# 15
# <class 'pandas.core.frame.DataFrame'>
# Index: 1813345 entries, 0 to 1813344
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   kd               float64
#  1   ligand_cid       float64
#  2   no_of_complexes  int64
#  3   protein_seq      object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 69.2+ MB
# None
# 16
# <class 'pandas.core.frame.DataFrame'>
# Index: 1934940 entries, 0 to 1934939
# Data columns (total 4 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   kd               float64
#  1   ligand_cid       float64
#  2   no_of_complexes  int64
#  3   protein_seq      object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 73.8+ MB
# None

# %%
df.to_csv('df_raw.csv', index = False)
